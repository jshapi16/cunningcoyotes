# %%
import pandas as pd
import numpy as np

# %%
inequality = pd.read_csv("final_datasets_inequality.csv")

# %%
inequality.head()
# Out:
#    Year    CPI  percentage_cpi  PCE_food_billions_of_dollars  \
# 0  1984  103.9             NaN                    291.100000
# 1  1985  107.6            3.56                    302.950000
# 2  1986  109.6            1.86                    316.416667
# 3  1987  113.6            3.65                    324.316667
# 4  1988  118.3            4.14                    342.791667
#
#    PCE_energy_goods_services_billions_of_dollars  PCE_food_percentage  \
# 0                                     193.091667                  NaN
# 1                                     199.541667                 4.07
# 2                                     178.583333                 4.45
# 3                                     185.341667                 2.50
# 4                                     194.075000                 5.70
#
#    PCE_energy_goods_services_percentage  GDP_in_Billions  percentage_gdp  \
# 0                                   NaN       4037.61400             NaN
# ...

# %%
inequality.to_html("inequality.html")
